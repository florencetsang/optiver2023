# %%
import optiver2023
env = optiver2023.make_env()
iter_test = env.iter_test()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Florence\Documents\Repo\optiver2023\optiver-trading-at-the-close\optiver-2023-basic-submission-demo.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Florence/Documents/Repo/optiver2023/optiver-trading-at-the-close/optiver-2023-basic-submission-demo.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import optiver2023
#       <a href='vscode-notebook-cell:/c%3A/Users/Florence/Documents/Repo/optiver2023/optiver-trading-at-the-close/optiver-2023-basic-submission-demo.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> env = optiver2023.make_env()
#       <a href='vscode-notebook-cell:/c%3A/Users/Florence/Documents/Repo/optiver2023/optiver-trading-at-the-close/optiver-2023-basic-submission-demo.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> iter_test = env.iter_test()
#
# File c:\Users\Florence\Documents\Repo\optiver2023\optiver-trading-at-the-close\optiver2023\__init__.py:2
# ----> 2 from .competition import make_env
#       4 __all__ = ['make_env']
#
# ModuleNotFoundError: No module named 'optiver2023.competition'

# %%
counter = 0
for (test, revealed_targets, sample_prediction) in iter_test:
    if counter == 0:
        print(test.head(3))
        print(revealed_targets.head(3))
        print(sample_prediction.head(3))
    sample_prediction['target'] = 0
    env.predict(sample_prediction)
    counter += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Florence\Documents\Repo\optiver2023\optiver-trading-at-the-close\optiver-2023-basic-submission-demo.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Florence/Documents/Repo/optiver2023/optiver-trading-at-the-close/optiver-2023-basic-submission-demo.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> counter = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Florence/Documents/Repo/optiver2023/optiver-trading-at-the-close/optiver-2023-basic-submission-demo.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> for (test, revealed_targets, sample_prediction) in iter_test:
#       <a href='vscode-notebook-cell:/c%3A/Users/Florence/Documents/Repo/optiver2023/optiver-trading-at-the-close/optiver-2023-basic-submission-demo.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>     if counter == 0:
#       <a href='vscode-notebook-cell:/c%3A/Users/Florence/Documents/Repo/optiver2023/optiver-trading-at-the-close/optiver-2023-basic-submission-demo.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>         print(test.head(3))
#
# NameError: name 'iter_test' is not defined
