# %%
# !pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ce/cd/a7c2cbffe2afff975349e60b14b63a448162145a7acac8ba12ddc2ed78a8/pandas-2.1.1-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy>=1.22.4 from https://files.pythonhosted.org/packages/cc/05/ef9fc04adda45d537619ea956bc33489f50a46badc949c4280d8309185ec/numpy-1.26.0-cp310-cp310-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.1 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.1 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.1 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.1 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.1 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.1 kB 186.2 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/61.1 kB 186.2 kB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
# DATA_PATH = '/kaggle/input'
DATA_PATH = '.'

# %%
df_train = pd.read_csv(f'{DATA_PATH}/optiver-trading-at-the-close/train.csv')
df_test = pd.read_csv(f'{DATA_PATH}/optiver-trading-at-the-close/example_test_files/test.csv')
revealed_targets = pd.read_csv(f'{DATA_PATH}/optiver-trading-at-the-close/example_test_files/revealed_targets.csv')
sample_submission = pd.read_csv(f'{DATA_PATH}/optiver-trading-at-the-close/example_test_files/sample_submission.csv')

# %%
display(df_train.tail())
display(df_test.tail())
display(revealed_targets.head())
display(revealed_targets.tail())
display(sample_submission.head())
display(sample_submission.tail())
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 5237975       195      480                540      2440722.89
# 5237976       196      480                540       349510.47
# 5237977       197      480                540            0.00
# 5237978       198      480                540      1000898.84
# 5237979       199      480                540      1884285.71
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 5237975                       -1         1.000317   28280361.74   0.999734
# 5237976                       -1         1.000643    9187699.11   1.000129
# 5237977                        0         0.995789   12725436.10   0.995789
# 5237978                        1         0.999210   94773271.05   0.999210
# 5237979                       -1         1.002129   24073677.32   1.000859
#
#          near_price  bid_price   bid_size  ask_price   ask_size       wap  \
# ...

# %%
display(df_train["stock_id"].value_counts())
display(df_test["stock_id"].value_counts())
# Out:
# stock_id
# 0      26455
# 137    26455
# 127    26455
# 128    26455
# 129    26455
#        ...
# 153    22605
# 199    21615
# 79     16500
# 135    15950
# 102    10230
# Name: count, Length: 200, dtype: int64
# stock_id
# 0      165
# 137    165
# 127    165
# 128    165
# 129    165
#       ...
# 69     165
# 70     165
# 71     165
# 72     165
# 199    165
# Name: count, Length: 200, dtype: int64

# %%
display(df_train["date_id"].value_counts())
display(df_test["date_id"].value_counts())
# Out:
# date_id
# 480    11000
# 353    11000
# 363    11000
# 362    11000
# 360    11000
#        ...
# 4      10560
# 2      10505
# 1      10505
# 3      10505
# 0      10505
# Name: count, Length: 481, dtype: int64
# date_id
# 478    11000
# 479    11000
# 480    11000
# Name: count, dtype: int64

# %%
display(df_train["seconds_in_bucket"].value_counts())
display(df_test["seconds_in_bucket"].value_counts())
# Out:
# seconds_in_bucket
# 0      95236
# 410    95236
# 300    95236
# 310    95236
# 320    95236
# 330    95236
# 340    95236
# 350    95236
# 360    95236
# 370    95236
# 380    95236
# 390    95236
# 400    95236
# 420    95236
# 280    95236
# 430    95236
# 440    95236
# 450    95236
# 460    95236
# 470    95236
# 480    95236
# 490    95236
# 500    95236
# 510    95236
# 520    95236
# 530    95236
# 290    95236
# 270    95236
# 10     95236
# 130    95236
# 20     95236
# 30     95236
# 40     95236
# 50     95236
# 60     95236
# 70     95236
# 80     95236
# 90     95236
# 100    95236
# 110    95236
# 120    95236
# 140    95236
# 260    95236
# 150    95236
# 160    95236
# 170    95236
# 180    95236
# 190    95236
# 200    95236
# 210    95236
# 220    95236
# 230    95236
# 240    95236
# 250    95236
# 540    95236
# Name: count, dtype: int64
# seconds_in_bucket
# 0      600
# 410    600
# 300    600
# 310    600
# 320    600
# 330    600
# 340    600
# 350    600
# ...

# %%
df_train[(df_train["stock_id"]==0) & (df_train["date_id"]==0)]
# Out:
#        stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0             0        0                  0      3180602.69
# 191           0        0                 10      1299772.70
# 382           0        0                 20      1299772.70
# 573           0        0                 30      1299772.70
# 764           0        0                 40      1218204.43
# 955           0        0                 50      1218204.43
# 1146          0        0                 60      1218204.43
# 1337          0        0                 70      1264494.89
# 1528          0        0                 80      1189832.86
# 1719          0        0                 90      1189272.89
# 1910          0        0                100      1249282.50
# 2101          0        0                110      1277280.77
# 2292          0        0                120      1216057.90
# 2483          0        0                130      1216057.90
# 2674          0        0                140      1104904.79
# ...

# %%
df_test[(df_test["stock_id"]==0) & (df_test["date_id"]==478)]
# Out:
#        stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0             0      478                  0      3753451.43
# 200           0      478                 10      3771174.79
# 400           0      478                 20      3771174.79
# 600           0      478                 30      4080903.36
# 800           0      478                 40      4045858.14
# 1000          0      478                 50      4045858.14
# 1200          0      478                 60      4045800.79
# 1400          0      478                 70      3996645.71
# 1600          0      478                 80      3996473.64
# 1800          0      478                 90      4161891.64
# 2000          0      478                100      4161891.64
# 2200          0      478                110      4084918.36
# 2400          0      478                120      4064441.86
# 2600          0      478                130      4161375.43
# 2800          0      478                140      4291346.71
# ...

# %%
revealed_targets[(revealed_targets["stock_id"]==0) & (revealed_targets["date_id"]==478)]
# Out:
#        stock_id  date_id  seconds_in_bucket  time_id  revealed_target  \
# 0           0.0      478                  0    26290        -2.310276
# 200         0.0      478                 10    26290        -7.200241
# 400         0.0      478                 20    26290        -7.500052
# 600         0.0      478                 30    26290       -12.480021
# 800         0.0      478                 40    26290        -9.570122
# 1000        0.0      478                 50    26290        -9.859800
# 1200        0.0      478                 60    26290       -10.719895
# 1400        0.0      478                 70    26290        -3.319979
# 1600        0.0      478                 80    26290        -2.890229
# 1800        0.0      478                 90    26290         1.640320
# 2000        0.0      478                100    26290        -1.119971
# 2200        0.0      478                110    26290         1.189709
# ...
